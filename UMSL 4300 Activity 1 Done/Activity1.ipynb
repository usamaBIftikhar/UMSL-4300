# %% [markdown]
# # Numpy and Python Activity

# %%
import numpy as np
np.random.seed(7)

# %%
# load pima indians dataset
dataset = np.loadtxt("https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv", delimiter=",")
print(data.shape)
# Out:
# (32561, 14)

# %%
print(data[0, :])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-8c271b9825a3> in <module>
# ----> 1 print(data[0, :])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078             casted_key = self._maybe_cast_indexer(key)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#    3082                 raise KeyError(key) from err
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0, slice(None, None, None))' is an invalid key

# %%
data.head()
# Out:
#    age  workclass  fnlwgt  education  educationNum  maritalStatus  \
# 0   39          3   77516         13            13              0
# 1   50          2   83311         13            13              1
# 2   38          1  215646         10             9              2
# 3   53          1  234721          6             7              1
# 4   28          1  338409         13            13              1
#
#    relationship  race  sex  capitalGain  capitalLoss  hoursPerWeek  country  \
# 0             0     1    1         2174            0            40        1
# 1             1     1    1            0            0            13        1
# 2             0     1    1            0            0            40        1
# 3             1     2    1            0            0            40        1
# 4             2     2    0            0            0            40       14
#
#    earnings
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
XTRAIN = dataset[:700,0:8]
YTRAIN = dataset[:700,8]
XVALIDATION = dataset[700:,0:8]
YVALIDATION = dataset[700:,8]

# %%
print(XTRAIN.shape)
print(YTRAIN.shape)
print(XVALIDATION.shape)
print(YVALIDATION.shape)
print(XTRAIN[0:3,])
print(YTRAIN[0:3])
print(XVALIDATION[0:3,])
print(YVALIDATION[0:3])

# %%
data.isnull().values.any()
# If there are blank cells
data = data.dropna()

# %%
data.describe()
# Out:
#                 age     workclass        fnlwgt     education  educationNum  \
# count  32561.000000  32561.000000  3.256100e+04  32561.000000  32561.000000
# mean      38.581647      1.622401  1.897784e+05     10.214766     10.080679
# std       13.640433      1.443345  1.055500e+05      2.692418      2.572720
# min       17.000000      0.000000  1.228500e+04      0.000000      1.000000
# 25%       28.000000      1.000000  1.178270e+05     10.000000      9.000000
# 50%       37.000000      1.000000  1.783560e+05     10.000000     10.000000
# 75%       48.000000      1.000000  2.370510e+05     11.000000     12.000000
# max       90.000000      8.000000  1.484705e+06     15.000000     16.000000
#
#        maritalStatus  relationship          race           sex   capitalGain  \
# count   32561.000000  32561.000000  32561.000000  32561.000000  32561.000000
# mean        1.083781      1.542397      1.180093      0.669205   1077.648844
# std         1.251381      1.437431      0.534266      0.470506   7385.292085
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         0.000000      0.000000      1.000000      0.000000      0.000000
# 50%         1.000000      1.000000      1.000000      1.000000      0.000000
# 75%         1.000000      3.000000      1.000000      1.000000      0.000000
# max         6.000000      5.000000      4.000000      1.000000  99999.000000
#
#         capitalLoss  hoursPerWeek       country      earnings
# count  32561.000000  32561.000000  32561.000000  32561.000000
# mean      87.303830     40.437456      2.305580      0.240810
# std      402.960219     12.347429      5.594557      0.427581
# min        0.000000      1.000000      0.000000      0.000000
# 25%        0.000000     40.000000      1.000000      0.000000
# 50%        0.000000     40.000000      1.000000      0.000000
# 75%        0.000000     45.000000      1.000000      0.000000
# max     4356.000000     99.000000     41.000000      1.000000

# %%
data['age'].value_counts()
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 85      3
# 88      3
# 86      1
# 87      1
# Name: age, Length: 73, dtype: int64

# %%
data.sort_values(by='age', ascending=False).head()
# Out:
#        age  workclass  fnlwgt  education  educationNum  maritalStatus  \
# 5406    90          1   51744         14            14              0
# 6624    90          1  313986          6             7              1
# 20610   90          1  206667         14            14              1
# 1040    90          1  137018         10             9              0
# 1935    90          1  221832         13            13              1
#
#        relationship  race  sex  capitalGain  capitalLoss  hoursPerWeek  \
# 5406              0     2    1            0            0            50
# 6624              1     1    1            0            0            40
# 20610             2     1    0            0            0            40
# 1040              0     1    0            0            0            40
# 1935              1     1    1            0            0            45
#
#        country  earnings
# 5406         1         1
# 6624         1         0
# 20610        1         1
# 1040         1         0
# 1935         1         0

# %%
data['age'].mean()
# Out:
# 38.58164675532078

# %%
from sklearn.utils import shuffle
data = shuffle(data)
data.head()
# Out:
#        age  workclass  fnlwgt  education  educationNum  maritalStatus  \
# 22204   34          1   55717         10             9              1
# 1128    41          2  154374         11            10              2
# 26780   42          6   78765         11            10              2
# 31694   58          1   85767         11            10              1
# 10932   18          0  216508          7             8              0
#
#        relationship  race  sex  capitalGain  capitalLoss  hoursPerWeek  \
# 22204             1     1    1            0         1848            50
# 1128              4     1    1            0            0            45
# 26780             4     1    1            0            0            90
# 31694             1     1    1            0            0            48
# 10932             0     1    1            0            0            25
#
#        country  earnings
# 22204        1         1
# 1128         1         0
# 26780        1         1
# 31694        1         0
# 10932        1         0
